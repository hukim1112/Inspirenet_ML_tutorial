# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url = requests.get("https://blog.naver.com/paransnow/221170996003")

# %%
soup = bs(url.text, "html.parser")

# %%
import codecs

import re

import collections
import requests
import time

from bs4 import BeautifulSoup

# %% [markdown]
# # reference : http://bluebead38.blogspot.kr/2017/06/python-beautifulsoup-txt.html

# %%
# --*-- coding: utf-8 --*--
import codecs

import re

import collections
import requests
import time

from bs4 import BeautifulSoup

# 에러 리스트 생성 함수
def insert_error(error, error_doc):
    for i in error_doc:
        error_log = str(error_doc[i]) + " / " + str(error_doc["page"]) + "page / " + str(error_doc["post_number"]) \
                    + "th post / " + error_doc["title"] \
                    + " / http://blog.naver.com/PostList.nhn?blogId=happy_inhatc&currentPage=" + str(
            error_doc["page"])
    error_list.append(error_log)



total_num = 0;

error_list = []

print("블로그 ID->")
blog_id = input()

print("\n탐색 시작 페이지 수->")
start_p = int(input())

print("\n탐색 종료 페이지 수->")
end_p = int(input())

print("\nCreating File Naver_Blog_Crawling_Result.txt...\n")

# 파일 열기
file = codecs.open("Naver_Blog_Crawling_Result.txt", 'w', encoding="utf-8")

# 페이지 단위
for page in range(start_p, end_p + 1):
    print("=" * 50)
    file.write("=" * 50 + "\n")

    doc = collections.OrderedDict()

    url = "http://blog.naver.com/PostList.nhn?blogId=" + blog_id + "&currentPage=" + str(page)
    r = requests.get(url)
    if (not r.ok):
        print("Page" + page + "연결 실패, Skip")
        continue

    # html 파싱
    soup = BeautifulSoup(r.text.encode("utf-8"), "html.parser")

    # 페이지 당 포스트 수 (printPost_# 형식의 id를 가진 태그 수)
    post_count = len(soup.find_all("table", {"id": re.compile("printPost.")}))

    doc["page"] = page

    # 포스트 단위
    for pidx in range(1, post_count + 1):
        print('-' * 50)
        file.write('-' * 50 + "\n")

        doc["post_number"] = pidx
        post = soup.find("table", {"id": "printPost" + str(pidx)})


        # 제목 찾기---------------------------

        title = post.find("h3", {"class": "se_textarea"})

        # 스마트에디터3 타이틀 제거 임시 적용 (클래스가 다름)
        if (title == None):
            title = post.find("span", {"class": "pcol1 itemSubjectBoldfont"})

        if (title != None):
            doc["title"] = title.text.strip()
        else:
            doc["title"] = "TITLE ERROR"


        # 날짜 찾기---------------------------

        date = post.find("span", {"class": "se_publishDate pcol2 fil5"})

        # 스마트에디터3 타이틀 제거 임시 적용 (클래스가 다름)
        if (date == None):
            date = post.find("p", {"class": "date fil5 pcol2 _postAddDate"})

        if (date != None):
            doc["date"] = date.text.strip()
        else:
            doc["date"] = "DATE ERROR"


        # 내용 찾기---------------------------

        content = post.find("div", {"class": "se_component_wrap sect_dsc __se_component_area"})

        # 스마트에디터3 타이틀 제거 임시 적용 (클래스가 다름)
        if (content == None):
            content = post.find("div", {"id": "postViewArea"})

        if (title != None):
            # Enter 5줄은 하나로
            doc["content"] = "\n" + content.text.strip().replace("\n" * 5, "\n")
        else:
            doc["content"] = "CONTENT ERROR"

        # doc 출력 (UnicodeError - 커맨드 창에서 실행 시 발생)
        for i in doc:

            str_doc = str(i) + ": " + str(doc[i])
            try:
                print(str_doc)
            except UnicodeError:
                print(str_doc.encode("utf-8"))

            file.write(str_doc + "\n")

            # 파일 쓰기
            if ("ERROR" in str(doc[i])):
                insert_error(doc[i], doc)

        #전체 수 증가
        total_num += 1

    


# 결과 출력 (전체 글 수, 에러 수)
print("=" * 50)
file.write("=" * 50 + "\n")

print("Total : " + str(total_num))

error_count = len(error_list)
print("Error : " + str(error_count))

# 에러가 있을 경우 출력
if (error_count != 0):
    print("Error Post : ")
    for i in error_list:
        print(i)

# 파일 닫기
file.close()

# %% [markdown]
# # url <- blogId + logNo

# %%
url = 'http://blog.naver.com/PostList.nhn?blogId=aromy0721&logNo=221163847740'

# %%
r = requests.get(url)


# html 파싱
soup = BeautifulSoup(r.text.encode("utf-8"), "html.parser")

# %%
    post_count = len(soup.find_all("table", {"id": re.compile("printPost.")}))

    doc["page"] = page

    # 포스트 단위
    for pidx in range(1, post_count + 1):
        print('-' * 50)

        doc["post_number"] = pidx
        post = soup.find("table", {"id": "printPost" + str(pidx)})


        # 제목 찾기---------------------------

        title = post.find("h3", {"class": "se_textarea"})

        # 스마트에디터3 타이틀 제거 임시 적용 (클래스가 다름)
        if (title == None):
            title = post.find("span", {"class": "pcol1 itemSubjectBoldfont"})

        if (title != None):
            doc["title"] = title.text.strip()
        else:
            doc["title"] = "TITLE ERROR"


        # 날짜 찾기---------------------------

        date = post.find("span", {"class": "se_publishDate pcol2 fil5"})

        # 스마트에디터3 타이틀 제거 임시 적용 (클래스가 다름)
        if (date == None):
            date = post.find("p", {"class": "date fil5 pcol2 _postAddDate"})

        if (date != None):
            doc["date"] = date.text.strip()
        else:
            doc["date"] = "DATE ERROR"


        # 내용 찾기---------------------------

        content = post.find("div", {"class": "se_component_wrap sect_dsc __se_component_area"})

        # 스마트에디터3 타이틀 제거 임시 적용 (클래스가 다름)
        if (content == None):
            content = post.find("div", {"id": "postViewArea"})

        if (title != None):
            # Enter 5줄은 하나로
            doc["content"] = "\n" + content.text.strip().replace("\n" * 5, "\n")
        else:
            doc["content"] = "CONTENT ERROR"
        print(content)
        # doc 출력 (UnicodeError - 커맨드 창에서 실행 시 발생)
#         for i in doc:

#             str_doc = str(i) + ": " + str(doc[i])
#             try:
#                 print(str_doc)
#             except UnicodeError:
#                 print(str_doc.encode("utf-8"))

#             file.write(str_doc + "\n")

#             # 파일 쓰기
#             if ("ERROR" in str(doc[i])):
#                 insert_error(doc[i], doc)

        #전체 수 증가
        total_num += 1
# Out:
# --------------------------------------------------
# <div class="se_component_wrap sect_dsc __se_component_area">
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><span>얼마전에 조카들을 보러 언니네 집에 다녀왔습니다<br/></span><span>가니까 이모한테 노래를 불러주겠다며 </span><span><b>블루투스 노래방 마이크</b></span><span>를 들고 나오더라구요<br/></span><span>5살짜리가 노래방 마이크를 들고 나오는데 어찌나 웃기던지<br/></span><span>장난감 마이크인줄 알았는데<br/></span><span>반주도 나오고 음질도 빵빵하게 잘 나오는 진짜 마이크더라구요<br/></span><span>신기해서 이게 뭐냐니까<br
E0NTI2NTQ5MjAy.2NX8P2Y4ysAK2vDvfDWJ1eQWpnssR11dFn0Rfu9Ap9og.TZADLPvfkMxKxKbjFcHwu2ObipLPLoDllTVjVNo774kg.JPEG.aromy0721/2.jpg?type=w1" style="cursor: pointer; rwidth:450px; rheight:600px;" width="450"/></div><div align="center" style="text-align: center;"><br/></div><div align="center" style="text-align: center;"><span style="font-size: 12pt;">매일 하나하나 압출하는 것도 일이지...ㅠ</span></div><div align="center" style="text-align: center;"><span style="font-size: 12pt;">거기다가 잘못 짜는 날에는 덧나서 흉터로 남아요</span></div><div align="center" style="text-align: center;"><span style="font-size: 12pt;">또 짠 다음에는 메이크업 자극될까봐</span></div><div align="center" style="text-align: center;"><span style="font-size: 12pt;">바르지도 못했던 게 일상이라고 할까...?</span></div><div align="center" style="text-align: center;"><br/></div><div align="center" style="text-align: center;"><img alt="" class="_photoImage" height="700" id="MjAxNzEyMjlfMjgx/MDAxNTE0NTI2NTQ5MzYy._z240ZbUkrhS3hfNG1cILqc6Obl5OsRJgkKx7Pl7Vd4g.4Dmzhrbri17h9NffZsa4g5ZjqjFGaCEgdqRIXqZQCLog.JPEG.aromy0721/3.jpg" onclick="popview(this, '90000003_00000000000000337EFAB66A')" src="http://postfiles1.naver.net/MjAxNzEyMjlfMjgx/MDAxNTE0NTI2NTQ5MzYy._z240ZbUkrhS3hfNG1cILqc6Obl5OsRJgkKx7Pl7Vd4g.4Dmzhrbri17h9NffZsa4g5ZjqjFGaCEgdqRIXqZQCLog.JPEG.aromy0721/3.jpg?type=w1" style="cursor: pointer; rwidth:525px; rheight:700px;" width="525"/></div><div align="center" style="text-align: center;"><br/></div><div align="center" style="text-align: center;"><br/></div><div align="center" style="text-align: center;"><span style="font-size: 12pt;">그러다가 얼마 전에 여드름인 탈출한 친구가</span></div><div align="center" style="text-align: center;"><span style="font-size: 12pt;">좋은 화장품 하나 소개시켜준다면서 덜컥 하나 선물해줬어요</span></div><div align="center" style="text-align: center;"><br/></div><div align="center" style="text-align: center;"><br/></div><div align="center" style="text-align: center;"><span style="font-size: 12pt;">바로 메디프런트의 NC크림~</span></div><div align="center" style="text-align: center;"><span style="font-size: 12pt;">메디프런트라는 브랜드는 처음 들어봐서 인터넷 검색 좀</span></div><div align="center" style="text-align: center;"><span style="font-size: 12pt;">했더니 이미 좋은 성분만 사용하는 브랜드로 좀 유명하더라고요.</span></div><div align="center" style="te ...
# </div>
# </div>
# --------------------------------------------------
# <div class="se_component_wrap sect_dsc __se_component_area">
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><span>얼굴이 커보이신 분들이라면 아무래도 저처럼<br/></span><span>스트레스, 콤플렉스가 되실 수 있을텐데요!<br/></span><span><br/></span><span>이목구비가 아무리 뚜렷하다 한들...<br/></span><span>전체적인 비율이 좋아보이지 않기 때문에<br/></span><span>외모 때문에 받는 고민이 상당하신 만큼<br/></span><span><br/></span><span>제가 요즘 얼굴갸름해지는법을 찾아보면서<br/></span><span>알게된 약속명가의 작은페이스관리 프로그램에<br/></span><span>대해서 여러분들에게도 소개시켜 드리려 합니다!</span><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_image default">
# <div class="se_sectionArea se_align-center">
# <div class="se_editArea">
# <div class="se_viewArea" style="max-width
/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><span>여기서는 다른곳과 달리 제품들까지 자체제작된<br/></span><span>제품을 사용하고 있어서 그런지 더욱 신뢰할 수 있구요!<br/></span><span>그래서 그런지 약손명가에서 얼굴갸름해지는법들을<br/></span><span>찾아오신분들이 많은 이유가 있는것 같더라구요!</span><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_image default">
# <div class="se_sectionArea se_align-center">
# <div class="se_editArea">
# <div class="se_viewArea" style="max-width:642px">
# <a class="se_mediaArea __se_image_link __se_link" data-linkdata='{"imgId" : "SEDOC-1514517343454-1393016618_image_10_img", "src" : "http://blogfiles.naver.net/MjAxNzEyMjlfNzkg/MDAxNTE0NTE2OTA3MTM3.lI2ob5rYF0R-jvLLjV7FcTQT3w93V3MrVFA2RrodOeEg.GkXiY55URSROJUsIjLpUJrQ2U9tNnfyZCozBJj08PKwg.JPEG.aromy0721/11.jpeg?type=w1", "linkUse" : "false", "link" : ""}' data-linktype="img" href="#" onclick="return false;">
# <img alt="" class="se_mediaImage __se_img_el" data-attachment-id="" height="441" id="SEDOC-1514517343454-1393016618_image_10_img" src="http://postfiles11.naver.net/MjAxNzEyMjlfNzkg/MDAxNTE0NTE2OTA3MTM3.lI2ob5rYF0R-jvLLjV7FcTQT3w93V3MrVFA2RrodOeEg.GkXiY55URSROJUsIjLpUJrQ2U9tNnfyZCozBJj08PKwg.JPEG.aromy0721/11.jpeg?type=w966" width="642"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><span>그리고 앞써 말씀드린 약손명가 책임제도 관리는<br/></span><span>총 20회의 관리를 1년 안에 모두 받으시면서<br/></span><span>시작과 끝나는 시점에 석고본을 떠서 처음에<br/></span><span>만들었던 석고본 위에 포개지지 않을 때에는<br/></span><span>무료로 더 관리를 해준다고 하는 제도입니다!!</span><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_image default">
# <div class="se_sectionArea se_align-center">
# <div class="se_editArea">
# <div class="se_viewArea" style="max-width:642px">
# <a class="se_mediaArea __se_image_link __se_link" data-linkdata='{"imgId" : "SEDOC-1514517343454-1393016618_image_11_img", "src" : "http://blogfiles.naver.net/MjAxNzEyMjlfMTky/MDAxNTE0NTE2OTA5ODk2.x3q6bKuf8pYR6QWPvR-ciEs4A_IXA6ZPESpfphCAwV0g.q-PTgtqIvPXIbvSh0N1pR3RSH-ECC2UFpTpSBCsEw2Yg.JPEG.aromy0721/12.jpeg?type=w1", "linkUse" : "false", "link" : ""}' data-linktype="img" href="#" onclick="return false;">
# <img alt="" class="se_mediaImage __se_img_el" data-attachment-id="" height="446" id="SEDOC-1514517343454-1393016618_image_11_img" src="http://postfiles10.naver.net/MjAxNzEyMjlfMTky/MDAxNTE0NTE2OTA5ODk2.x3q6bKuf8pYR6QWPvR-ciEs4A_IXA6ZPESpfphCAwV0g.q-PTgtqIvPXIbvSh0N1pR3RSH-ECC2UFpTpSBCsEw2Yg.JPEG.aromy0721/12.jpeg?type=w966" width="642"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><span>얼굴갸름해지는법이번에 약손명가에서<br/></span><span>제대로 받게되면서 작은페이스로 되는 기대가<br/></span><span>너무나도 큰 만큼 얼른 20회를 다 받고<br/></span><span>저도 석고본 포개보고 싶네요 ㅋ.ㅋ<br/></span><span><br/></span><span></span><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_video default">
# <div class="se_sectionArea se_align-justify">
# <div class="se_editArea">
# <div class="se_viewArea">
# <div class="se_mediaArea" data-attachment-id="VxB9iFkI1tRBUnXMi2LXaP6e64Ic" id="SEDOC-1514517343454-1393016618_video_0">
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_video", "docVersion" : "1.0", "id" :"SEDOC-1514517343454-1393016618_video_0" , "data" : { "baseElId" : "SEDOC-1514517343454-1393016618_video_0", "videoType" : "player", "vid" : "0D61AFB3BF569EF6F964B21FA7062EFA1C02", "inkey" : "V129678c4d4b6011444cbf50a90352df3e3d12478c5a300000731bb9f82d7366e92cdf50a90352df3e3d1", "width": "854", "height": "480", "displayWidth": "", "displayHeight": ""}}' type="text/data"></script>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_video default">
# <div class="se_sectionArea se_align-justify">
# <div class="se_editArea">
# <div class="se_viewArea">
# <div class="se_mediaArea" data-attachment-id="V97I5GZtmkppWSCTpiV0ifNoJR8w" id="SEDOC-1514517343454-1393016618_video_1">
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_video", "docVersion" : "1.0", "id" :"SEDOC-1514517343454-1393016618_video_1" , "data" : { "baseElId" : "SEDOC-1514517343454-1393016618_video_1", "videoType" : "player", "vid" : "395B6A444E0D201A6B8757707F7CE007402B", "inkey" : "V12752c2e610f9a4f38c6e28a3185736eb520126a738dff4e6743c2fd3289914bb24fe28a3185736eb520", "width": "854", "height": "480", "displayWidth": "", "displayHeight": ""}}' type="text/data"></script>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_video default">
# <div class="se_sectionArea se_align-justify">
# <div class="se_editArea">
# <div class="se_viewArea">
# <div class="se_mediaArea" data-attachment-id="Vdi6sfXLWS9gBr_CPu8bzBlkjmEY" id="SEDOC-1514517343454-1393016618_video_2">
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_video", "docVersion" : "1.0", "id" :"SEDOC-1514517343454-1393016618_video_2" , "data" : { "baseElId" : "SEDOC-1514517343454-1393016618_video_2", "videoType" : "player", "vid" : "3CD0BF62AEEF6C03F73E539917A6A68D3809", "inkey" : "V1238660d9767dcc06955f53799c16064515375068c2ca5a4ad30ae5d6e4f01bbe46df53799c160645153", "width": "854", "height": "480", "displayWidth": "", "displayHeight": ""}}' type="text/data"></script>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_video default">
# <div class="se_sectionArea se_align-justify">
# <div class="se_editArea">
# <div class="se_viewArea">
# <div class="se_mediaArea" data-attachment-id="Vq5dgRd4BntJIzdxjr_--7CfYqos" id="SEDOC-1514517343454-1393016618_video_3">
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_video", "docVersion" : "1.0", "id" :"SEDOC-1514517343454-1393016618_video_3" , "data" : { "baseElId" : "SEDOC-1514517343454-1393016618_video_3", "videoType" : "player", "vid" : "5534D515E1F81F5E61595CAA732847BA922E", "inkey" : "V123b4b029205bcf0799f200e27ac94ef2c97e98efe07df79b493e9dbea0767068bec200e27ac94ef2c97", "width": "854", "height": "480", "displayWidth": "", "displayHeight": ""}}' type="text/data"></script>
# <div class="se_component se_video default">
# <div class="se_sectionArea se_align-justify">
# <div class="se_editArea">
# <div class="se_viewArea">
# <div class="se_mediaArea" data-attachment-id="Vdoysb6TQABE8mZVVTDB7uPqAcHs" id="SEDOC-1514517343454-1393016618_video_4">
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_video", "docVersion" : "1.0", "id" :"SEDOC-1514517343454-1393016618_video_4" , "data" : { "baseElId" : "SEDOC-1514517343454-1393016618_video_4", "videoType" : "player", "vid" : "95925ECEA10CB102E5074C831C2E49B3A308", "inkey" : "V1274209abf0058b0ecfc9fbac37c07f8cbb8b6d2d7a4c776c087654db2cb8cf234cd9fbac37c07f8cbb8", "width": "854", "height": "480", "displayWidth": "", "displayHeight": ""}}' type="text/data"></script>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_video default">
# <div class="se_sectionArea se_align-justify">
# <div class="se_editArea">
# <div class="se_viewArea">
# <div class="se_mediaArea" data-attachment-id="VZuqiyB133xTBP51VtdhVP8ONFMA" id="SEDOC-1514517343454-1393016618_video_5">
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_video", "docVersion" : "1.0", "id" :"SEDOC-1514517343454-1393016618_video_5" , "data" : { "baseElId" : "SEDOC-1514517343454-1393016618_video_5", "videoType" : "player", "vid" : "4D9905FBA415C8236362E71C9A0671098EBB", "inkey" : "V12772ccca10ee47b5b9466c1332fe810ca4af22ab3591627183bc48ec485a9d5b96166c1332fe810ca4a", "width": "854", "height": "480", "displayWidth": "", "displayHeight": ""}}' type="text/data"></script>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_video default">
# <div class="se_sectionArea se_align-justify">
# <div class="se_editArea">
# <div class="se_viewArea">
# <div class="se_mediaArea" data-attachment-id="VzDwgL1qrjkfEsqFjVHe_zQaL0a8" id="SEDOC-1514517343454-1393016618_video_6">
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_video", "docVersion" : "1.0", "id" :"SEDOC-1514517343454-1393016618_video_6" , "data" : { "baseElId" : "SEDOC-1514517343454-1393016618_video_6", "videoType" : "player", "vid" : "133C3003BF9B83B9CA046AC265F0176E6ECC", "inkey" : "V122ab046c23d30f8cf6d0e798e7b382bb0e83ec5ae39befa4744d048afc56cbb7a6b0e798e7b382bb0e8", "width": "854", "height": "480", "displayWidth": "", "displayHeight": ""}}' type="text/data"></script>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="se_component se_video default">
# <div class="se_sectionArea se_align-justify">
# <div class="se_editArea">
# <div class="se_viewArea">
# <div class="se_mediaArea" data-attachment-id="V2F8WsVbaVO31qs-El1TwwiHyq9Q" id="SEDOC-1514517343454-1393016618_video_7">
# </div>
# </div>
# </div>
# </div>
# </div>
# <script class="__se_module_data" data-module='{"type":"v1_video", "docVersion" : "1.0", "id" :"SEDOC-1514517343454-1393016618_video_7" , "data" : { "baseElId" : "SEDOC-1514517343454-1393016618_video_7", "videoType" : "player", "vid" : "191683C3329408AD26E6C10964006B52B35C", "inkey" : "V1238a50ebb384f9dcfe21d496879eb567a69c11f3358f58876c561dbcbcbe58dc1301d496879eb567a69", "width": "854", "height": "480", "displayWidth": "", "displayHeight": ""}}' type="text/data"></script>
# <div class="se_component se_paragraph default">
# <div class="se_sectionArea">
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_T3 se_align-center">
# <div class="se_editView">
# <div class="se_textView">
# <p class="se_textarea"><!-- SE3-TEXT { --><!-- } SE3-TEXT --></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
